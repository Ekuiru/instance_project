# %%
from ultralytics import YOLO

# %%
DATA_PATH = r"E:\Education\debts\3 course 2 semester\Practice\Datasets\LaRS_fusion\instance_yolo_dataset.yaml"
MODEL_NAME = "yolo26n-seg.pt"

# %%
model = YOLO(MODEL_NAME)

model.train(
    data=DATA_PATH,
    epochs=80,
    imgsz=640,
    batch=9,
    device=0,
    workers=2,
    project=r"E:\Education\debts\3 course 2 semester\Practice\yolo_nano",
    name="yolo26n_base",
    save=True,
    plots=True,
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.41 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.26  Python-3.11.15 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# ...

# %%
model = YOLO(r"E:\Education\debts\3 course 2 semester\Practice\yolo_nano\yolo26n_base\weights\best.pt")
metrics = model.val(
    data=DATA_PATH,
    project=r"E:\Education\debts\3 course 2 semester\Practice\yolo_nano\metrics",
)

print("    BOX    ")
print(f"Precision: {metrics.box.mp:.3f}")
print(f"Recall: {metrics.box.mr:.3f}")
print(f"mAP50: {metrics.box.map50:.3f}")
print(f"mAP50-95: {metrics.box.map:.3f}")

print("\n    SEG    ")
print(f"Precision: {metrics.seg.mp:.3f}")
print(f"Recall: {metrics.seg.mr:.3f}")
print(f"mAP50: {metrics.seg.map50:.3f}")
print(f"mAP50-95: {metrics.seg.map:.3f}")
# Out:
# Ultralytics 8.4.26  Python-3.11.15 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# YOLO26n-seg summary (fused): 139 layers, 2,690,444 parameters, 0 gradients, 9.0 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 2187.0817.3 MB/s, size: 331.6 KB)
# val: Scanning E:\Education\debts\3 course 2 semester\Practice\Datasets\LaRS_fusion\instance_yolo\val\labels.cache... 198 images, 38 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 198/198  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.9s0.1s
#                    all        198       1071      0.518      0.334      0.333      0.184      0.481      0.299      0.266      0.129
#                   boat        133        852       0.52      0.506      0.487      0.277      0.477      0.465      0.448      0.222
# ...

# %%
model.predict(
    source=r"E:\Education\debts\3 course 2 semester\Practice\Datasets\LaRS_fusion\instance_yolo\val\images",
    project=r"E:\Education\debts\3 course 2 semester\Practice\yolo_nano\val",
    save=True,
    conf=0.25
)
# Out:
# image 1/198 E:\Education\debts\3 course 2 semester\Practice\Datasets\LaRS_fusion\instance_yolo\val\images\davimar_seq_08_00008.jpg: 384x640 2 boats, 1 rowboat, 53.0ms
# image 2/198 E:\Education\debts\3 course 2 semester\Practice\Datasets\LaRS_fusion\instance_yolo\val\images\davimar_seq_08_00037.jpg: 384x640 1 boat, 3 rowboats, 18.5ms
# image 3/198 E:\Education\debts\3 course 2 semester\Practice\Datasets\LaRS_fusion\instance_yolo\val\images\davimar_seq_36_00024.jpg: 384x640 (no detections), 15.7ms
# image 4/198 E:\Education\debts\3 course 2 semester\Practice\Datasets\LaRS_fusion\instance_yolo\val\images\davimar_seq_36_00062.jpg: 384x640 1 rowboat, 16.9ms
# image 5/198 E:\Education\debts\3 course 2 semester\Practice\Datasets\LaRS_fusion\instance_yolo\val\images\davimar_seq_36_00141.jpg: 384x640 2 rowboats, 16.4ms
# image 6/198 E:\Education\debts\3 course 2 semester\Practice\Datasets\LaRS_fusion\instance_yolo\val\images\davimar_seq_36_00210.jpg: 384x640 3 rowboats, 36.1ms
# ...

# %%
print("Обучение Yolo завершено!")
# Out:
# Обучение Yolo завершено!
